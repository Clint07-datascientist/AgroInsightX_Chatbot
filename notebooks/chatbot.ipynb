# %%
from datasets import load_dataset

dataset_name = "KisanVaani/agriculture-qa-english-only"
dataset = load_dataset(dataset_name, split="train") # Load the 'train' split
print(dataset)
print(dataset[0]) # Inspect the first example
